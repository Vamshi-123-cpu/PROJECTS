# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import random, string
import pyperclip
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate

# Initialize Tkinter window
root = tk.Tk()
root.geometry("600x400")
root.title("Language Translation")

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
tk.Label(root, text="Language Translation", font="arial 20 bold").pack(pady=10)

# Input text box
inputtext = tk.Text(root, height=5, width=50)
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
tk.OptionMenu(root, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(root, height=5, width=50)
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Buttons
tk.Button(root, text="Translate", command=translate_text, bg='#4CAF50', fg='white', font='arial 12', width=15).pack(pady=5)
tk.Button(root, text="Copy", command=copy_text, bg='#2196F3', fg='white', font='arial 12', width=15).pack(pady=5)
tk.Button(root, text="Save Audio", command=save_audio, bg='#f44336', fg='white', font='arial 12', width=15).pack(pady=5)
tk.Button(root, text="Exit", command=root.quit, bg='#000000', fg='white', font='arial 12', width=15).pack(pady=5)

# Run the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")  # Adjust the window size
root.title("Language Translation")

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
tk.Label(root, text="Language Translation", font="arial 24 bold", bg='#ADD8E6').pack(pady=20)

frame = tk.Frame(root, bg='#ADD8E6')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='arial 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
tk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='arial 12', bg='#F0F0F0')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#ADD8E6')
button_frame.pack(pady=10)

tk.Button(button_frame, text="Translate", command=translate_text, bg='#4CAF50', fg='white', font='arial 12', width=15).grid(row=0, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Copy", command=copy_text, bg='#2196F3', fg='white', font='arial 12', width=15).grid(row=0, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Save Audio", command=save_audio, bg='#f44336', fg='white', font='arial 12', width=15).grid(row=0, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Clear", command=clear_text, bg='#FFC107', fg='black', font='arial 12', width=15).grid(row=1, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Exit", command=exit_app, bg='#000000', fg='white', font='arial 12', width=15).grid(row=1, column=1, padx=10, pady=10)

# Run the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#f0f0f0')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#f0f0f0').pack(pady=20)

frame = tk.Frame(root, bg='#f0f0f0')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
tk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#ffffff')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#f0f0f0')
button_frame.pack(pady=20)

tk.Button(button_frame, text="Translate", command=translate_text, bg='#4CAF50', fg='white', font='Helvetica 12', width=15).grid(row=0, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Copy", command=copy_text, bg='#2196F3', fg='white', font='Helvetica 12', width=15).grid(row=0, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Save Audio", command=save_audio, bg='#f44336', fg='white', font='Helvetica 12', width=15).grid(row=0, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Clear", command=clear_text, bg='#FFC107', fg='black', font='Helvetica 12', width=15).grid(row=1, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Exit", command=exit_app, bg='#000000', fg='white', font='Helvetica 12', width=15).grid(row=1, column=1, padx=10, pady=10)

root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#f0f0f0')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#f0f0f0').pack(pady=20)

frame = tk.Frame(root, bg='#f0f0f0')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
tk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#ffffff')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to clear only the output text box
def clear_output():
    outputtext.delete("1.0", tk.END)

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#f0f0f0')
button_frame.pack(pady=20)

tk.Button(button_frame, text="Translate", command=translate_text, bg='#4CAF50', fg='white', font='Helvetica 12', width=15).grid(row=0, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Copy", command=copy_text, bg='#2196F3', fg='white', font='Helvetica 12', width=15).grid(row=0, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Save Audio", command=save_audio, bg='#f44336', fg='white', font='Helvetica 12', width=15).grid(row=0, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Clear", command=clear_text, bg='#FFC107', fg='black', font='Helvetica 12', width=15).grid(row=1, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Clear Output", command=clear_output, bg='#FF9800', fg='black', font='Helvetica 12', width=15).grid(row=1, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Reverse Translate", command=reverse_translate, bg='#673AB7', fg='white', font='Helvetica 12', width=15).grid(row=1, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Translate Multiple", command=translate_multiple, bg='#3F51B5', fg='white', font='Helvetica 12', width=15).grid(row=2, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Exit", command=exit_app, bg='#000000', fg='white', font='Helvetica 12', width=15).grid(row=2, column=1, padx=10, pady=10)

root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
tk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to clear only the output text box
def clear_output():
    outputtext.delete("1.0", tk.END)

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

tk.Button(button_frame, text="Translate", command=translate_text, bg='#4CAF50', fg='white', font='Helvetica 12', width=15).grid(row=0, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Copy", command=copy_text, bg='#2196F3', fg='white', font='Helvetica 12', width=15).grid(row=0, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Save Audio", command=save_audio, bg='#f44336', fg='white', font='Helvetica 12', width=15).grid(row=0, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Clear", command=clear_text, bg='#FFC107', fg='black', font='Helvetica 12', width=15).grid(row=1, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Clear Output", command=clear_output, bg='#FF9800', fg='black', font='Helvetica 12', width=15).grid(row=1, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Reverse Translate", command=reverse_translate, bg='#673AB7', fg='white', font='Helvetica 12', width=15).grid(row=1, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Translate Multiple", command=translate_multiple, bg='#3F51B5', fg='white', font='Helvetica 12', width=15).grid(row=2, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Exit", command=exit_app, bg='#000000', fg='white', font='Helvetica 12', width=15).grid(row=2, column=1, padx=10, pady=10)

root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
tk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to clear only the output text box
def clear_output():
    outputtext.delete("1.0", tk.END)

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to reset all fields
def reset_all():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)
    choice.set(langlist[0])

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Styling for buttons
button_style = {'font': 'Helvetica 12', 'width': 15, 'bd': 2, 'relief': 'raised'}

tk.Button(button_frame, text="Translate", command=translate_text, bg='#4CAF50', fg='white', **button_style).grid(row=0, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Copy", command=copy_text, bg='#2196F3', fg='white', **button_style).grid(row=0, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Save Audio", command=save_audio, bg='#f44336', fg='white', **button_style).grid(row=0, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Clear", command=clear_text, bg='#FFC107', fg='black', **button_style).grid(row=1, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Clear Output", command=clear_output, bg='#FF9800', fg='black', **button_style).grid(row=1, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Reverse Translate", command=reverse_translate, bg='#673AB7', fg='white', **button_style).grid(row=1, column=2, padx=10, pady=10)
tk.Button(button_frame, text="Translate Multiple", command=translate_multiple, bg='#3F51B5', fg='white', **button_style).grid(row=2, column=0, padx=10, pady=10)
tk.Button(button_frame, text="Reset All", command=reset_all, bg='#009688', fg='white', **button_style).grid(row=2, column=1, padx=10, pady=10)
tk.Button(button_frame, text="Exit", command=exit_app, bg='#000000', fg='white', **button_style).grid(row=2, column=2, padx=10, pady=10)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to clear only the output text box
def clear_output():
    outputtext.delete("1.0", tk.END)

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to reset all fields
def reset_all():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)
    choice.set(langlist[0])

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

# Create buttons
ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton').grid(row=0, column=0, padx=10, pady=10)
ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton').grid(row=0, column=1, padx=10, pady=10)
ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton').grid(row=0, column=2, padx=10, pady=10)
ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton').grid(row=1, column=0, padx=10, pady=10)
ttk.Button(button_frame, text="Clear Output", command=clear_output, style='TButton').grid(row=1, column=1, padx=10, pady=10)
ttk.Button(button_frame, text="Reverse Translate", command=reverse_translate, style='TButton').grid(row=1, column=2, padx=10, pady=10)
ttk.Button(button_frame, text="Translate Multiple", command=translate_multiple, style='TButton').grid(row=2, column=0, padx=10, pady=10)
ttk.Button(button_frame, text="Reset All", command=reset_all, style='TButton').grid(row=2, column=1, padx=10, pady=10)
ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton').grid(row=2, column=2, padx=10, pady=10)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
import os
from gtts import gTTS
import base64
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to clear only the output text box
def clear_output():
    outputtext.delete("1.0", tk.END)

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to reset all fields
def reset_all():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)
    choice.set(langlist[0])

# Function to exit the application
def exit_app():
    root.quit()

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

# Create button with hover effect
def on_enter(e):
    e.widget['background'] = '#76C7C0'

def on_leave(e):
    e.widget['background'] = '#4CAF50'

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Clear Output", command=clear_output, style='TButton'),
    ttk.Button(button_frame, text="Reverse Translate", command=reverse_translate, style='TButton'),
    ttk.Button(button_frame, text="Translate Multiple", command=translate_multiple, style='TButton'),
    ttk.Button(button_frame, text="Reset All", command=reset_all, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", on_enter)
    button.bind("<Leave>", on_leave)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to clear only the output text box
def clear_output():
    outputtext.delete("1.0", tk.END)

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to reset all fields
def reset_all():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)
    choice.set(langlist[0])

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Clear Output", command=clear_output, style='TButton'),
    ttk.Button(button_frame, text="Reverse Translate", command=reverse_translate, style='TButton'),
    ttk.Button(button_frame, text="Translate Multiple", command=translate_multiple, style='TButton'),
    ttk.Button(button_frame, text="Reset All", command=reset_all, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 131, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 134, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 131, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 134, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 131, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 134, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 131, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 134, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 131, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 134, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 131, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_18564\1934120655.py", line 134, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to save translated text to a file
def save_translated_text():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            file_path = filedialog.asksaveasfilename(defaultextension=".txt", filetypes=[("Text files", "*.txt")])
            if file_path:
                with open(file_path, "w", encoding="utf-8") as file:
                    file.write(output_text)
                messagebox.showinfo("Save Success", f"Translated text saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Save Text Error", str(e))

# Function to translate text to a set of preferred languages
def translate_preferred():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            preferred_langs = ['fr', 'de', 'es']  # Example preferred languages
            translated_texts = {}
            for lang in preferred_langs:
                translated_texts[lang] = translate(input_text, lang)
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Preferred Translation Error", str(e))

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Save Translated Text", command=save_translated_text, style='TButton'),
    ttk.Button(button_frame, text="Reverse Translate", command=reverse_translate, style='TButton'),
    ttk.Button(button_frame, text="Translate Multiple", command=translate_multiple, style='TButton'),
    ttk.Button(button_frame, text="Translate Preferred", command=translate_preferred, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip
import os

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to speak the translated text
def speak_text():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            tts.save("temp.mp3")
            os.system("temp.mp3")
            os.remove("temp.mp3")
        else:
            messagebox.showwarning("Output Error", "No translated text to speak.")
    except Exception as e:
        messagebox.showerror("Speak Text Error", str(e))

# Function to translate text to a set of preferred languages
def translate_preferred():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            preferred_langs = ['fr', 'de', 'es']  # Example preferred languages
            translated_texts = {}
            for lang in preferred_langs:
                translated_texts[lang] = translate(input_text, lang)
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Preferred Translation Error", str(e))

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to translate text to multiple languages
def translate_multiple():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_texts = {}
            for lang in langlist:
                translated_texts[lang] = translate(input_text, lang_array[lang])
            outputtext.delete("1.0", tk.END)
            for lang, text in translated_texts.items():
                outputtext.insert(tk.END, f"{lang}:\n{text}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Multiple Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Speak Text", command=speak_text, style='TButton'),
    ttk.Button(button_frame, text="Reverse Translate", command=reverse_translate, style='TButton'),
    ttk.Button(button_frame, text="Translate Multiple", command=translate_multiple, style='TButton'),
    ttk.Button(button_frame, text="Translate Preferred", command=translate_preferred, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 153, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2945203066.py", line 156, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip
import os
from langdetect import detect

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to speak the translated text
def speak_text():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            tts.save("temp.mp3")
            os.system("temp.mp3")
            os.remove("temp.mp3")
        else:
            messagebox.showwarning("Output Error", "No translated text to speak.")
    except Exception as e:
        messagebox.showerror("Speak Text Error", str(e))

# Function to detect the language of the input text
def detect_language():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            detected_lang = detect(input_text)
            messagebox.showinfo("Detected Language", f"The detected language is: {detected_lang}")
        else:
            messagebox.showwarning("Input Error", "Please enter text to detect its language.")
    except Exception as e:
        messagebox.showerror("Language Detection Error", str(e))

# Function to provide text statistics
def text_statistics():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            word_count = len(input_text.split())
            char_count = len(input_text)
            stats_message = f"Word Count: {word_count}\nCharacter Count: {char_count}"
            messagebox.showinfo("Text Statistics", stats_message)
        else:
            messagebox.showwarning("Input Error", "Please enter text to get its statistics.")
    except Exception as e:
        messagebox.showerror("Text Statistics Error", str(e))

# Function to reverse translate the text
def reverse_translate():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            original_text = translate(output_text, 'en')
            inputtext.delete("1.0", tk.END)
            inputtext.insert(tk.END, original_text)
        else:
            messagebox.showwarning("Output Error", "No translated text to reverse.")
    except Exception as e:
        messagebox.showerror("Reverse Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Speak Text", command=speak_text, style='TButton'),
    ttk.Button(button_frame, text="Reverse Translate", command=reverse_translate, style='TButton'),
    ttk.Button(button_frame, text="Detect Language", command=detect_language, style='TButton'),
    ttk.Button(button_frame, text="Text Statistics", command=text_statistics, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 147, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_13904\2773950103.py", line 150, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ------------------- ---------------- 524.3/981.5 kB 357.1 kB/s eta 0:00:02
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ---------------------------- ------- 786.4/981.5 kB 524.3 kB/s eta 0:00:01
#      ------------------------------------ 981.5/981.5 kB 300.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993250 sha256=978d3f497d212c069c75a85b2d1efe61587a0b69963fe7864b381397250f27ca
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip
import os
from langdetect import detect
from transformers import pipeline

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to speak the translated text
def speak_text():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            tts.save("temp.mp3")
            os.system("temp.mp3")
            os.remove("temp.mp3")
        else:
            messagebox.showwarning("Output Error", "No translated text to speak.")
    except Exception as e:
        messagebox.showerror("Speak Text Error", str(e))

# Function to detect the language of the input text
def detect_language():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            detected_lang = detect(input_text)
            messagebox.showinfo("Detected Language", f"The detected language is: {detected_lang}")
        else:
            messagebox.showwarning("Input Error", "Please enter text to detect its language.")
    except Exception as e:
        messagebox.showerror("Language Detection Error", str(e))

# Function to provide text statistics
def text_statistics():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            word_count = len(input_text.split())
            char_count = len(input_text)
            stats_message = f"Word Count: {word_count}\nCharacter Count: {char_count}"
            messagebox.showinfo("Text Statistics", stats_message)
        else:
            messagebox.showwarning("Input Error", "Please enter text to get its statistics.")
    except Exception as e:
        messagebox.showerror("Text Statistics Error", str(e))

# Function to summarize the text
def summarize_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            summarizer = pipeline("summarization")
            summarized_text = summarizer(input_text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, summarized_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to summarize.")
    except Exception as e:
        messagebox.showerror("Summarization Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Speak Text", command=speak_text, style='TButton'),
    ttk.Button(button_frame, text="Summarize Text", command=summarize_text, style='TButton'),
    ttk.Button(button_frame, text="Detect Language", command=detect_language, style='TButton'),
    ttk.Button(button_frame, text="Text Statistics", command=text_statistics, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip
import os
from langdetect import detect

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to speak the translated text
def speak_text():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            tts.save("temp.mp3")
            os.system("temp.mp3")
            os.remove("temp.mp3")
        else:
            messagebox.showwarning("Output Error", "No translated text to speak.")
    except Exception as e:
        messagebox.showerror("Speak Text Error", str(e))

# Function to provide text statistics
def text_statistics():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            word_count = len(input_text.split())
            char_count = len(input_text)
            stats_message = f"Word Count: {word_count}\nCharacter Count: {char_count}"
            messagebox.showinfo("Text Statistics", stats_message)
        else:
            messagebox.showwarning("Input Error", "Please enter text to get its statistics.")
    except Exception as e:
        messagebox.showerror("Text Statistics Error", str(e))

# Function to summarize the text
def summarize_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            summarizer = pipeline("summarization")
            summarized_text = summarizer(input_text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, summarized_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to summarize.")
    except Exception as e:
        messagebox.showerror("Summarization Error", str(e))

# Function to translate text into multiple languages
def multiple_translation():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translations = {lang: translate(input_text, lang_array[lang]) for lang in langlist}
            outputtext.delete("1.0", tk.END)
            for language, translation in translations.items():
                outputtext.insert(tk.END, f"{language}:\n{translation}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Speak Text", command=speak_text, style='TButton'),
    ttk.Button(button_frame, text="Summarize Text", command=summarize_text, style='TButton'),
    ttk.Button(button_frame, text="Multiple Translation", command=multiple_translation, style='TButton'),
    ttk.Button(button_frame, text="Text Statistics", command=text_statistics, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 150, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 153, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 150, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 153, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 150, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 153, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 150, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 153, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 150, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 153, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 150, in button_hover
#     event.widget['background'] = '#76C7C0'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10176\971191025.py", line 153, in button_leave
#     event.widget['background'] = '#4CAF50'
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1727, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1716, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1706, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-background"

# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/10.6 MB 2.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/10.6 MB 2.7 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/10.6 MB 2.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/10.6 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.6 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/10.6 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.6 MB 3.6 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 4.6 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pandas as pd
from gtts import gTTS
from mtranslate import translate
import pyperclip
import os
from langdetect import detect
import pygame

# Initialize Tkinter window
root = tk.Tk()
root.geometry("800x600")
root.title("Language Translation")

# Apply a theme for better styling
style = ttk.Style()
style.theme_use('clam')

# Read language dataset
df = pd.read_csv(r"D:\ABCDEFG\N_Batch -- 5.30PM\4. JULY\22nd- Twitter sentiment analysis\MULTIPLE LANGUAGE TRANSLATION\MULTIPLE LANGUAGE TRANSLATION\language.csv")
df.dropna(inplace=True)
lang = df['name'].to_list()
langlist = tuple(lang)
langcode = df['iso'].to_list()

# Create dictionary of language and 2 letter langcode
lang_array = {lang[i]: langcode[i] for i in range(len(langcode))}

# Layout
root.configure(bg='#E8F0FE')  # Set background color
tk.Label(root, text="Language Translation", font="Helvetica 24 bold", bg='#E8F0FE').pack(pady=20)

frame = tk.Frame(root, bg='#E8F0FE')
frame.pack(pady=10)

# Input text box
inputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12')
inputtext.pack(pady=10)

# Language selection dropdown
choice = tk.StringVar()
choice.set(langlist[0])
ttk.OptionMenu(frame, choice, *langlist).pack(pady=10)

# Output text box
outputtext = tk.Text(frame, height=5, width=50, font='Helvetica 12', bg='#F5F5F5')
outputtext.pack(pady=10)

# Function to translate text
def translate_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translated_text = translate(input_text, lang_array[choice.get()])
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, translated_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to copy translated text
def copy_text():
    output_text = outputtext.get("1.0", tk.END).strip()
    pyperclip.copy(output_text)
    messagebox.showinfo("Copy Success", "Translated text copied to clipboard!")

# Function to save audio file of translated text
def save_audio():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            file_path = filedialog.asksaveasfilename(defaultextension=".mp3", filetypes=[("MP3 files", "*.mp3")])
            if file_path:
                tts.save(file_path)
                messagebox.showinfo("Save Success", f"Audio file saved as {file_path}")
        else:
            messagebox.showwarning("Output Error", "No translated text to save.")
    except Exception as e:
        messagebox.showerror("Audio Save Error", str(e))

# Function to clear input and output text boxes
def clear_text():
    inputtext.delete("1.0", tk.END)
    outputtext.delete("1.0", tk.END)

# Function to speak the translated text
def speak_translation_text():
    try:
        output_text = outputtext.get("1.0", tk.END).strip()
        if output_text:
            tts = gTTS(text=output_text, lang=lang_array[choice.get()], slow=False)
            tts.save("temp.mp3")
            pygame.mixer.init()
            pygame.mixer.music.load("temp.mp3")
            pygame.mixer.music.play()
            while pygame.mixer.music.get_busy():
                continue
            os.remove("temp.mp3")
        else:
            messagebox.showwarning("Output Error", "No translated text to speak.")
    except Exception as e:
        messagebox.showerror("Speak Text Error", str(e))

# Function to provide text statistics
def text_statistics():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            word_count = len(input_text.split())
            char_count = len(input_text)
            stats_message = f"Word Count: {word_count}\nCharacter Count: {char_count}"
            messagebox.showinfo("Text Statistics", stats_message)
        else:
            messagebox.showwarning("Input Error", "Please enter text to get its statistics.")
    except Exception as e:
        messagebox.showerror("Text Statistics Error", str(e))

# Function to summarize the text
def summarize_text():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            summarizer = pipeline("summarization")
            summarized_text = summarizer(input_text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
            outputtext.delete("1.0", tk.END)
            outputtext.insert(tk.END, summarized_text)
        else:
            messagebox.showwarning("Input Error", "Please enter text to summarize.")
    except Exception as e:
        messagebox.showerror("Summarization Error", str(e))

# Function to translate text into multiple languages
def multiple_translation():
    try:
        input_text = inputtext.get("1.0", tk.END).strip()
        if input_text:
            translations = {lang: translate(input_text, lang_array[lang]) for lang in langlist}
            outputtext.delete("1.0", tk.END)
            for language, translation in translations.items():
                outputtext.insert(tk.END, f"{language}:\n{translation}\n\n")
        else:
            messagebox.showwarning("Input Error", "Please enter text to translate.")
    except Exception as e:
        messagebox.showerror("Translation Error", str(e))

# Function to exit the application
def exit_app():
    root.quit()

# Add button animations and text animations
def button_hover(event):
    event.widget['background'] = '#76C7C0'

def button_leave(event):
    event.widget['background'] = '#4CAF50'

def text_animation():
    inputtext.tag_configure('blink', background='yellow')
    current_tags = inputtext.tag_names('insert')
    if 'blink' in current_tags:
        inputtext.tag_remove('blink', 'insert')
    else:
        inputtext.tag_add('blink', 'insert')
    root.after(500, text_animation)

# Buttons
button_frame = tk.Frame(frame, bg='#E8F0FE')
button_frame.pack(pady=20)

# Define button styles
style.configure('TButton', font='Helvetica 12', padding=6)
style.configure('TButton', background='#4CAF50', foreground='white')

buttons = [
    ttk.Button(button_frame, text="Translate", command=translate_text, style='TButton'),
    ttk.Button(button_frame, text="Copy", command=copy_text, style='TButton'),
    ttk.Button(button_frame, text="Save Audio", command=save_audio, style='TButton'),
    ttk.Button(button_frame, text="Clear", command=clear_text, style='TButton'),
    ttk.Button(button_frame, text="Speak Translation Text", command=speak_translation_text, style='TButton'),
    ttk.Button(button_frame, text="Summarize Text", command=summarize_text, style='TButton'),
    ttk.Button(button_frame, text="Multiple Translation", command=multiple_translation, style='TButton'),
    ttk.Button(button_frame, text="Text Statistics", command=text_statistics, style='TButton'),
    ttk.Button(button_frame, text="Exit", command=exit_app, style='TButton')
]

for i, button in enumerate(buttons):
    button.grid(row=i//3, column=i%3, padx=10, pady=10)
    button.bind("<Enter>", button_hover)
    button.bind("<Leave>", button_leave)

# Start text animation
text_animation()

root.mainloop()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
